# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('data_classic.csv', delimiter=';')
df1.head()
# Out:
#            Название игры            Ресторан        Дата День недели  \
# 0  Квиз, плиз!  SPB #174  Street Food Bar №1  26.06.2019          Ср
# 1  Квиз, плиз!  SPB #174  Street Food Bar №1  26.06.2019          Ср
# 2  Квиз, плиз!  SPB #174  Street Food Bar №1  26.06.2019          Ср
# 3  Квиз, плиз!  SPB #174  Street Food Bar №1  26.06.2019          Ср
# 4  Квиз, плиз!  SPB #174  Street Food Bar №1  26.06.2019          Ср
#
#    Номер пакета      Название команды  Последний раунд  Всего баллов  Место
# 0             1           Геннна и Ко             16.0          51.0      1
# 1             1  Отвечает Борис Бурда             13.0          46.0      2
# 2             1       N веселых гусей             16.0          45.0      3
# 3             1       In vino veritas             11.0          43.0      4
# 4             1        Полная дикость             10.0          43.0      5

# %%
df1[df1['Название команды'] == 'Funny cucumber'].head()
# Out:
#             Название игры   Ресторан        Дата День недели  Номер пакета  \
# 27507  [новички] SPB #615       ЦИНЬ  27.01.2023          Пт             1
# 28920  [новички] SPB #630  Хали-Гали  01.03.2023          Ср             1
# 29630  [новички] SPB #636       ЦИНЬ  17.03.2023          Пт             1
# 30704  [новички] SPB #643       ЦИНЬ  07.04.2023          Пт             1
# 31387  [новички] SPB #650      PALMA  21.04.2023          Пт             1
#
#       Название команды  Последний раунд  Всего баллов  Место
# 27507   Funny cucumber              8.0          31.0     11
# 28920   Funny cucumber             14.0          39.0      2
# 29630   Funny cucumber              6.0          28.0     18
# 30704   Funny cucumber             15.0          38.0      6
# 31387   Funny cucumber              5.0          29.0     14

# %%
df1['Название команды'].unique()
# Out:
# array(['Геннна и Ко', 'Отвечает Борис Бурда', 'N веселых гусей', ...,
#        'Окрошка на просекко', 'О, Чиназес', 'Смыв'], dtype=object)

# %%
df = pd.read_excel('data_thematic_kim.xlsx')
df.head()
# Out:
#                        Название игры   Ресторан   Дата День недели  \
# 0  [кино и музыка] рашн эдишн SPB #3  Хали-Гали  10.04          Вс
# 1  [кино и музыка] рашн эдишн SPB #3  Хали-Гали  10.04          Вс
# 2  [кино и музыка] рашн эдишн SPB #3  Хали-Гали  10.04          Вс
# 3  [кино и музыка] рашн эдишн SPB #3  Хали-Гали  10.04          Вс
# 4  [кино и музыка] рашн эдишн SPB #3  Хали-Гали  10.04          Вс
#
#    Номер пакета Название команды  Последний раунд  Всего баллов  Место
# 0             1   Жизнь и грабля               18          67.5      1
# 1             1             1?=!               19          67.0      2
# 2             1           Ракета               22          66.0      3
# 3             1         Broforce               18          63.0      4
# 4             1  Последнее место               18          63.0      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Название игры     5826 non-null   object
#  1   Ресторан          5826 non-null   object
#  2   Дата              5826 non-null   float64
#  3   День недели       5826 non-null   object
#  4   Номер пакета      5826 non-null   int64
#  5   Название команды  5826 non-null   object
#  6   Последний раунд   5826 non-null   int64
#  7   Всего баллов      5826 non-null   float64
#  8   Место             5826 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 409.8+ KB

# %%
print(df.columns)
# Out:
# Index(['Название игры', 'Ресторан', 'Дата', 'День недели', 'Номер пакета',
#        'Название команды', 'Последний раунд', 'Всего баллов', 'Место'],
#       dtype='object')

# %%
teams = df.groupby('Название команды')

# %%
teams['Название игры'].head()
# Out:
# 0       [кино и музыка] рашн эдишн SPB #3
# 1       [кино и музыка] рашн эдишн SPB #3
# 2       [кино и музыка] рашн эдишн SPB #3
# 3       [кино и музыка] рашн эдишн SPB #3
# 4       [кино и музыка] рашн эдишн SPB #3
#                       ...
# 5821                     [караоке] SPB #2
# 5822                     [караоке] SPB #2
# 5823                     [караоке] SPB #2
# 5824                     [караоке] SPB #2
# 5825                     [караоке] SPB #2
# Name: Название игры, Length: 4245, dtype: object

# %%
for team, data_team in teams:

    days_of_week = data_team['День недели'].value_counts()
    popular_day = days_of_week.idxmax

    #restaurants = data_team['Ресторан'].value_counts()
    #popular_restaurant = restaurants.idxmax

    print(f"Команда {team}:")
    print(days_of_week)
    #print(restaurants)
# Out:
# Команда !интим не предлагать!:
# Чт    1
# Name: День недели, dtype: int64
# Команда "Epic Fail":
# Пт    1
# Name: День недели, dtype: int64
# Команда "Капиталисты":
# Пт    1
# Name: День недели, dtype: int64
# Команда #40team:
# Чт    1
# Name: День недели, dtype: int64
# Команда #НеЧушпаны:
# Вс    1
# Name: День недели, dtype: int64
# Команда #Под принуждением:
# Чт    1
# Name: День недели, dtype: int64
# Команда #вотэтоповорот!:
# Сб    1
# Name: День недели, dtype: int64
# Команда #качкивгороде:
# Сб    1
# Name: День недели, dtype: int64
# Команда #развелибазар:
# Вс    1
# Сб    1
# Name: День недели, dtype: int64
# Команда 'Название потом придумаем':
# Сб    1
# Name: День недели, dtype: int64
# Команда .ля, мажоры:
# Пт    1
# Name: День недели, dtype: int64
# Команда 1+1:
# Вс    2
# Вт    1
# Name: День недели, dtype: int64
# Команда 10:
# Чт    3
# Name: День недели, dtype: int64
# Команда 1000км до мечты:
# Вс    3
# Пт    1
# Сб    1
# ...

# %%
data_dict = {}

# Получение уникальных названий команд
unique_teams = df['Название команды'].unique()

# Итерация по уникальным командам
for team in unique_teams:
    # Фильтрация данных для текущей команды
    team_data = df[df['Название команды'] == team].copy()
    # Удаление столбца с названием команды, чтобы он не дублировался внутри каждого подфрейма
    team_data.drop(columns=['Название команды'], inplace=True)
    # Сохранение подфрейма в словаре, используя название команды в качестве ключа
    data_dict[team] = team_data

# %%
data_dict['Funny cucumber'].head()
# Out:
#                           Название игры           Ресторан   Дата День недели  \
# 3348  [про кино] Властелин колец SPB #1  Ресторан ParkKing  25.05          Чт
# 3414                  [про кино] SPB #3            Puberty   3.06          Сб
# 3579                [шазам] 90-е SPB #2            Puberty   1.07          Сб
# 3653              [music party] SPB #11            Puberty  11.07          Вт
# 3827              [music party] SPB #12            Puberty  13.08          Вс
#
#       Номер пакета  Последний раунд  Всего баллов  Место
# 3348             2               16          43.5      9
# 3414             1               12          46.0     11
# 3579             2                9          45.0      7
# 3653             1               11          66.0     21
# 3827             2               14          75.0     10

# %%
data_dict['Истина в пиве, короче...'].head(10)
# Out:
#                                           Название игры        Ресторан  \
# 162                         [music party] 2000-х SPB #1       Хали-Гали
# 312                         [кино и музыка] 90-х SPB #2         Puberty
# 408                           [про кино] Сумерки SPB #1         Puberty
# 641                       [кино и музыка] 2000-х SPB #3       Хали-Гали
# 934                     [music party] рашн эдишн SPB #1       Хали-Гали
# 1050                           [про кино] 2010-х SPB #1  Дворец Олимпия
# 1206  Церемония открытия сезона игр [кино и музыка] ...            ЦИНЬ
# 1445                        [кино и музыка] 90-х SPB #3         Puberty
# 1691                      [кино и музыка] 2000-х SPB #4       Хали-Гали
# 1934                                  [про кино] SPB #2       Хали-Гали
#
#        Дата День недели  Номер пакета  Последний раунд  Всего баллов  Место
# 162   27.04          Ср             1               10          70.0     19
# ...

# %%
fun_cum = data_dict['Funny cucumber'].reset_index(drop=True)
fun_cum.shape[0]
# Out:
# 19

# %%
data_dict['Funny cucumber'].head()
# Out:
#                           Название игры           Ресторан   Дата День недели  \
# 3348  [про кино] Властелин колец SPB #1  Ресторан ParkKing  25.05          Чт
# 3414                  [про кино] SPB #3            Puberty   3.06          Сб
# 3579                [шазам] 90-е SPB #2            Puberty   1.07          Сб
# 3653              [music party] SPB #11            Puberty  11.07          Вт
# 3827              [music party] SPB #12            Puberty  13.08          Вс
#
#       Номер пакета  Последний раунд  Всего баллов  Место
# 3348             2               16          43.5      9
# 3414             1               12          46.0     11
# 3579             2                9          45.0      7
# 3653             1               11          66.0     21
# 3827             2               14          75.0     10

# %%
dumasbrod_package =  data_dict['Дюмасброды'].groupby('Номер пакета').agg({'Место': [('Игр', lambda x: x.count()),
                                                        ('Топ 5', lambda x: (x <= 5).sum()),
                                                        ('Топ 1', lambda x: (x == 1).sum())]})

# %%
dumasbrod_package.rename({'Место': 'Количество'}, axis=1)
# Out:
#              Количество
#                     Игр Топ 5 Топ 1
# Номер пакета
# 1                     7     2     1
# 2                     7     5     0
# 3                    11     9     3
# 4                     2     2     2
# 5                     1     1     1
